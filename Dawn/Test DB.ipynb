# %%
#Imports
import pandas as pd
import matplotlib.pyplot as plt
import psycopg2
from config import user
from config import password
#import data
from sqlalchemy import create_engine
engine = create_engine(f'postgresql://{user}:{password}@localhost:5432/StemDemographics')

# %%
#test plot data in pandas
data = engine.execute("""SELECT * FROM stem_major_demographics;""")

major=pd.DataFrame(data)
major.head()
# Out:
#    0     1                                          2            3     4  \
# 0  1  2419                      PETROLEUM ENGINEERING  Engineering  2339
# 1  2  2416             MINING AND MINERAL ENGINEERING  Engineering   756
# 2  3  2415                  METALLURGICAL ENGINEERING  Engineering   856
# 3  4  2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING  Engineering  1258
# 4  5  2418                        NUCLEAR ENGINEERING  Engineering  2573
#
#       5    6         7       8
# 0  2057  282  0.120564  110000
# 1   679   77  0.101852   75000
# 2   725  131  0.153037   73000
# 3  1123  135  0.107313   70000
# 4  2200  373  0.144967   65000

# %%
major.columns = ['Rank', 'Major_Code','Major','Major_category', 'Total', 'Men', 'Women', 'ShareWomen', 'Median']
major.head()
# Out:
#    Rank  Major_Code                                      Major Major_category  \
# 0     1        2419                      PETROLEUM ENGINEERING    Engineering
# 1     2        2416             MINING AND MINERAL ENGINEERING    Engineering
# 2     3        2415                  METALLURGICAL ENGINEERING    Engineering
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING    Engineering
# 4     5        2418                        NUCLEAR ENGINEERING    Engineering
#
#    Total   Men  Women  ShareWomen  Median
# 0   2339  2057    282    0.120564  110000
# 1    756   679     77    0.101852   75000
# 2    856   725    131    0.153037   73000
# 3   1258  1123    135    0.107313   70000
# 4   2573  2200    373    0.144967   65000

# %%
#Data Stem employee
data2 = engine.execute("""SELECT * FROM stem_employee_demographics;""")

emp=pd.DataFrame(data2)
emp.head()
# Out:
#       0             1                2      3      4     5     6     7     8  \
# 0  2014       Country  U.S. Population  50.79  49.21  64.0   4.0  16.0  12.0
# 1  2014  Social Media         Facebook  31.00  69.00  57.0  34.0   4.0   2.0
# 2  2014  Social Media        Instagram  31.00  69.00  57.0  34.0   4.0   2.0
# 3  2014  Social Media          Google+  30.00  70.00  61.0  30.0   3.0   2.0
# 4  2014  Social Media          YouTube  30.00  70.00  61.0  30.0   3.0   2.0
#
#      9   10  11
# 0  1.0  3.0 NaN
# 1  3.0  NaN NaN
# 2  3.0  NaN NaN
# 3  4.0  NaN NaN
# 4  4.0  NaN NaN

# %%
emp.columns = ['Date', 'Type','Company','Female', 'Male', 'White', 'Asian', 'Latino', 'Black','Mutli', 'Other', 'Undeclared']
emp.head()
# Out:
#    Date          Type          Company  Female   Male  White  Asian  Latino  \
# 0  2014       Country  U.S. Population   50.79  49.21   64.0    4.0    16.0
# 1  2014  Social Media         Facebook   31.00  69.00   57.0   34.0     4.0
# 2  2014  Social Media        Instagram   31.00  69.00   57.0   34.0     4.0
# 3  2014  Social Media          Google+   30.00  70.00   61.0   30.0     3.0
# 4  2014  Social Media          YouTube   30.00  70.00   61.0   30.0     3.0
#
#    Black  Mutli  Other  Undeclared
# 0   12.0    1.0    3.0         NaN
# 1    2.0    3.0    NaN         NaN
# 2    2.0    3.0    NaN         NaN
# 3    2.0    4.0    NaN         NaN
# 4    2.0    4.0    NaN         NaN

# %%
emp_data_df = emp [['Date', 'Type', 'Company', 'Female', 'Male']]
emp_data_df
# Out:
#      Date          Type              Company  Female   Male
# 0    2014       Country      U.S. Population   50.79  49.21
# 1    2014  Social Media             Facebook   31.00  69.00
# 2    2014  Social Media            Instagram   31.00  69.00
# 3    2014  Social Media              Google+   30.00  70.00
# 4    2014  Social Media              YouTube   30.00  70.00
# ..    ...           ...                  ...     ...    ...
# 157  2018          Tech              Netflix   43.00  57.00
# 158  2018          Tech                 Yelp   54.00  46.00
# 159  2018        Entity  DiversityInc top 50   44.00  56.00
# 160  2018        Entity     Fortune 500 CEOs    6.00  94.00
# 161  2018    Government          US Congress   20.00  80.00
#
# [162 rows x 5 columns]

# %%
emp_data_df.dtypes
# Out:
# Date         int64
# Type        object
# Company     object
# Female     float64
# Male       float64
# dtype: object

# %%
emp_data_df.to_csv(r'Path where you want to store the exported CSV file\File Name.csv')

# %%
emp_data_df['Date'].astype(object)
#emp_data_df.dtypes
# Out:
# 0      2014
# 1      2014
# 2      2014
# 3      2014
# 4      2014
#        ...
# 157    2018
# 158    2018
# 159    2018
# 160    2018
# 161    2018
# Name: Date, Length: 162, dtype: object

# %%
emp_data_df.dtypes
# Out:
# Date         int64
# Type        object
# Company     object
# Female     float64
# Male       float64
# dtype: object

# %%
#Read .csv to sql
pd.read_csv("Data/earthquake.csv").to_sql(name="earthquake", con=create_engine("sqlite:///my_db.sqlite"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-df8ed04f9b1e> in <module>
# ----> 1 emp.to_json(r'Path to store the exported JSON file\emp.json')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_json(self, path_or_buf, orient, date_format, double_precision, force_ascii, date_unit, default_handler, lines, compression, index, indent)
#    2362             compression=compression,
#    2363             index=index,
# -> 2364             indent=indent,
#    2365         )
#    2366
#
# ~\anaconda3\lib\site-packages\pandas\io\json\_json.py in to_json(path_or_buf, obj, orient, date_format, double_precision, force_ascii, date_unit, default_handler, lines, compression, index, indent)
#      90
#      91     if isinstance(path_or_buf, str):
# ---> 92         fh, handles = get_handle(path_or_buf, "w", compression=compression)
#      93         try:
#      94             fh.write(s)
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     429         elif is_text:
#     430             # No explicit encoding
# --> 431             f = open(path_or_buf, mode, errors="replace", newline="")
#     432         else:
#     433             # Binary mode
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Path to store the exported JSON file\\emp.json'
